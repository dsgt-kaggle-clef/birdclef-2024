# %%
from birdclef.utils import get_spark
from IPython.display import Image, display

spark = get_spark()
display(spark)

# read straight from the bucket
df_meta = spark.read.csv(
    "gs://dsgt-clef-birdclef-2024/data/raw/birdclef-2023/train_metadata.csv"
)
df_meta.printSchema()
df_meta.show(vertical=True, n=1, truncate=100)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/23 22:17:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/23 22:17:47 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://birdclef-dev.us-central1-a.c.dsgt-clef-2024.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#
# -RECORD 0----------------
#  _c0  | primary_label
#  _c1  | secondary_labels
#  _c2  | type
#  _c3  | latitude
#  _c4  | longitude
#  _c5  | scientific_name
#  _c6  | common_name
#  _c7  | author
#  _c8  | license
#  _c9  | rating
#  _c10 | url
#  _c11 | filename
# only showing top 1 row

# %%
df_meta.show(n=5)
# Out:
# +-------------+----------------+--------+--------+---------+------------------+--------------------+-------------+--------------------+------+--------------------+--------------------+
# |          _c0|             _c1|     _c2|     _c3|      _c4|               _c5|                 _c6|          _c7|                 _c8|   _c9|                _c10|                _c11|
# +-------------+----------------+--------+--------+---------+------------------+--------------------+-------------+--------------------+------+--------------------+--------------------+
# |primary_label|secondary_labels|    type|latitude|longitude|   scientific_name|         common_name|       author|             license|rating|                 url|            filename|
# |      abethr1|              []|['song']|  4.3906|  38.2788|Turdus tephronotus|African Bare-eyed...|Rolf A. de By|Creative Commons ...|   4.0|https://www.xeno-...|abethr1/XC128013.ogg|
# |      abethr1|              []|['call']| -2.9524|  38.2921|Turdus tephronotus|African Bare-eyed...|James Bradley|Creative Commons ...|   3.5|https://www.xeno-...|abethr1/XC363501.ogg|
# |      abethr1|              []|['song']| -2.9524|  38.2921|Turdus tephronotus|African Bare-eyed...|James Bradley|Creative Commons ...|   3.5|https://www.xeno-...|abethr1/XC363502.ogg|
# |      abethr1|              []|['song']| -2.9524|  38.2921|Turdus tephronotus|African Bare-eyed...|James Bradley|Creative Commons ...|   5.0|https://www.xeno-...|abethr1/XC363503.ogg|
# +-------------+----------------+--------+--------+---------+------------------+--------------------+-------------+--------------------+------+--------------------+--------------------+
# only showing top 5 rows

# %%
import os
from pathlib import Path

in_root = Path("data/raw/birdclef-2023/train_audio")
out_dir = Path("data/encodec_embeddings")

os.makedirs(out_dir, exist_ok=True)

out_path = out_dir / "embeddings.parquet"

# %%
from encodec import EncodecModel
import torchaudio

bandwidth = 3.0
model = EncodecModel.encodec_model_24khz()
model.set_target_bandwidth(bandwidth)
# Out:
# /home/acheung/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
import torch
from encodec.utils import convert_audio

def compress(file):
    # Load and pre-process the audio waveform
    wav, sr = torchaudio.load(in_root / file)
    wav = convert_audio(wav, sr, model.sample_rate, model.channels)
    wav = wav.unsqueeze(0)

    # Extract discrete codes from EnCodec
    with torch.no_grad():
        encoded_frames = model.encode(wav)
    codes = torch.cat([encoded[0] for encoded in encoded_frames], dim=-1)
    
    return codes[0].flatten().numpy()

# %%
compress("eaywag1/XC639588.ogg").shape
# Out:
# (9740,)

# %%
df_meta_pd = df_meta.toPandas()
df_meta_pd.columns = df_meta_pd.iloc[0]
df_meta_pd = df_meta_pd.drop(df_meta_pd.index[0])
df_meta_pd
# Out:
# 0     primary_label secondary_labels              type latitude longitude  \
# 1           abethr1               []          ['song']   4.3906   38.2788
# 2           abethr1               []          ['call']  -2.9524   38.2921
# 3           abethr1               []          ['song']  -2.9524   38.2921
# 4           abethr1               []          ['song']  -2.9524   38.2921
# 5           abethr1               []  ['call', 'song']  -2.9524   38.2921
# ...             ...              ...               ...      ...       ...
# 16937       yewgre1               []              ['']  -1.2502   29.7971
# 16938       yewgre1               []              ['']  -1.2489   29.7923
# 16939       yewgre1               []              ['']  -1.2433   29.7844
# 16940       yewgre1               []              ['']   0.0452   36.3699
# 16941       yewgre1               []              ['']  -0.3986   37.3087
#
# 0           scientific_name                common_name          author  \
# 1        Turdus tephronotus   African Bare-eyed Thrush   Rolf A. de By
# 2        Turdus tephronotus   African Bare-eyed Thrush   James Bradley
# 3        Turdus tephronotus   African Bare-eyed Thrush   James Bradley
# 4        Turdus tephronotus   African Bare-eyed Thrush   James Bradley
# 5        Turdus tephronotus   African Bare-eyed Thrush   James Bradley
# ...                     ...                        ...             ...
# 16937  Eurillas latirostris  Yellow-whiskered Greenbul  András Schmidt
# 16938  Eurillas latirostris  Yellow-whiskered Greenbul  András Schmidt
# 16939  Eurillas latirostris  Yellow-whiskered Greenbul  András Schmidt
# 16940  Eurillas latirostris  Yellow-whiskered Greenbul   Lars Lachmann
# 16941  Eurillas latirostris  Yellow-whiskered Greenbul   Lars Lachmann
#
# 0                                                license rating  \
# 1      Creative Commons Attribution-NonCommercial-Sha...    4.0
# 2      Creative Commons Attribution-NonCommercial-Sha...    3.5
# 3      Creative Commons Attribution-NonCommercial-Sha...    3.5
# 4      Creative Commons Attribution-NonCommercial-Sha...    5.0
# 5      Creative Commons Attribution-NonCommercial-Sha...    4.5
# ...                                                  ...    ...
# 16937  Creative Commons Attribution-NonCommercial-Sha...    3.0
# 16938  Creative Commons Attribution-NonCommercial-Sha...    4.0
# 16939  Creative Commons Attribution-NonCommercial-Sha...    4.0
# 16940  Creative Commons Attribution-NonCommercial-Sha...    4.0
# 16941  Creative Commons Attribution-NonCommercial-Sha...    4.5
#
# 0                                    url              filename
# 1      https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 2      https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 3      https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 4      https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 5      https://www.xeno-canto.org/363504  abethr1/XC363504.ogg
# ...                                  ...                   ...
# 16937      https://xeno-canto.org/703472  yewgre1/XC703472.ogg
# 16938      https://xeno-canto.org/703485  yewgre1/XC703485.ogg
# 16939      https://xeno-canto.org/704433  yewgre1/XC704433.ogg
# 16940      https://xeno-canto.org/752974  yewgre1/XC752974.ogg
# 16941      https://xeno-canto.org/753190  yewgre1/XC753190.ogg
#
# [16941 rows x 12 columns]

# %%
df_meta_head = df_meta_pd.head(5)
df_meta_head
# Out:
# 0 primary_label secondary_labels              type latitude longitude  \
# 1       abethr1               []          ['song']   4.3906   38.2788
# 2       abethr1               []          ['call']  -2.9524   38.2921
# 3       abethr1               []          ['song']  -2.9524   38.2921
# 4       abethr1               []          ['song']  -2.9524   38.2921
# 5       abethr1               []  ['call', 'song']  -2.9524   38.2921
#
# 0     scientific_name               common_name         author  \
# 1  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 5  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
# 0                                            license rating  \
# 1  Creative Commons Attribution-NonCommercial-Sha...    4.0
# 2  Creative Commons Attribution-NonCommercial-Sha...    3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...    3.5
# 4  Creative Commons Attribution-NonCommercial-Sha...    5.0
# 5  Creative Commons Attribution-NonCommercial-Sha...    4.5
#
# 0                                url              filename
# 1  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 2  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 3  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 4  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 5  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg

# %%
df_meta_head.loc[:, "embeddings"] = df_meta_head.loc[:, "filename"].apply(compress)
df_meta_head
# Out:
# /tmp/ipykernel_1628/1343728804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meta_head.loc[:, "embeddings"] = df_meta_head.loc[:, "filename"].apply(compress)
# 0 primary_label secondary_labels              type latitude longitude  \
# 1       abethr1               []          ['song']   4.3906   38.2788
# 2       abethr1               []          ['call']  -2.9524   38.2921
# 3       abethr1               []          ['song']  -2.9524   38.2921
# 4       abethr1               []          ['song']  -2.9524   38.2921
# 5       abethr1               []  ['call', 'song']  -2.9524   38.2921
#
# 0     scientific_name               common_name         author  \
# 1  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 5  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
# 0                                            license rating  \
# 1  Creative Commons Attribution-NonCommercial-Sha...    4.0
# 2  Creative Commons Attribution-NonCommercial-Sha...    3.5
# 3  Creative Commons Attribution-NonCommercial-Sha...    3.5
# 4  Creative Commons Attribution-NonCommercial-Sha...    5.0
# 5  Creative Commons Attribution-NonCommercial-Sha...    4.5
#
# 0                                url              filename  \
# 1  https://www.xeno-canto.org/128013  abethr1/XC128013.ogg
# 2  https://www.xeno-canto.org/363501  abethr1/XC363501.ogg
# 3  https://www.xeno-canto.org/363502  abethr1/XC363502.ogg
# 4  https://www.xeno-canto.org/363503  abethr1/XC363503.ogg
# 5  https://www.xeno-canto.org/363504  abethr1/XC363504.ogg
#
# 0                                         embeddings
# 1  [865, 835, 821, 151, 798, 798, 176, 176, 176, ...
# 2  [62, 62, 62, 62, 408, 408, 835, 835, 835, 835,...
# 3  [62, 62, 62, 62, 408, 408, 408, 408, 408, 408,...
# 4  [62, 1019, 432, 1017, 999, 724, 228, 724, 430,...
# 5  [62, 62, 62, 62, 408, 408, 408, 408, 408, 408,...

# %%
df_meta_head.loc[1, 'embeddings'].shape
# Out:
# (13688,)

# %%
test_path = out_dir / "test.parquet"
df_meta_head.to_parquet(test_path)

# %%
from tqdm import tqdm

tqdm.pandas()
df_meta_pd.loc[:, "embeddings"] = df_meta_pd.loc[:, "filename"].progress_apply(compress)
# Out:
#   0%|          | 0/16941 [00:00<?, ?it/s]
#   0%|          | 42/16941 [02:13<14:52:46,  3.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 from tqdm import tqdm
#       3 tqdm.pandas()
# ----> 4 df_meta_pd.loc[:, "embeddings"] = df_meta_pd.loc[:, "filename"].progress_apply(compress)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[4], line 12, in compress(file)
#      10 # Extract discrete codes from EnCodec
#      11 with torch.no_grad():
# ---> 12     encoded_frames = model.encode(wav)
#      13 codes = torch.cat([encoded[0] for encoded in encoded_frames], dim=-1)
#      15 return codes[0].flatten().numpy()
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/model.py:144, in EncodecModel.encode(self, x)
#     142 for offset in range(0, length, stride):
#     143     frame = x[:, :, offset: offset + segment_length]
# --> 144     encoded_frames.append(self._encode_frame(frame))
#     145 return encoded_frames
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/model.py:161, in EncodecModel._encode_frame(self, x)
#     158 else:
#     159     scale = None
# --> 161 emb = self.encoder(x)
#     162 codes = self.quantizer.encode(emb, self.frame_rate, self.bandwidth)
#     163 codes = codes.transpose(0, 1)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/modules/seanet.py:144, in SEANetEncoder.forward(self, x)
#     143 def forward(self, x):
# --> 144     return self.model(x)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/modules/seanet.py:63, in SEANetResnetBlock.forward(self, x)
#      62 def forward(self, x):
# ---> 63     return self.shortcut(x) + self.block(x)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/modules/conv.py:204, in SConv1d.forward(self, x)
#     201 extra_padding = get_extra_padding_for_conv1d(x, kernel_size, stride, padding_total)
#     202 if self.causal:
#     203     # Left padding for causal
# --> 204     x = pad1d(x, (padding_total, extra_padding), mode=self.pad_mode)
#     205 else:
#     206     # Asymmetric padding required for odd strides
#     207     padding_right = padding_total // 2
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/encodec/modules/conv.py:92, in pad1d(x, paddings, mode, value)
#      90     extra_pad = max_pad - length + 1
#      91     x = F.pad(x, (0, extra_pad))
# ---> 92 padded = F.pad(x, paddings, mode, value)
#      93 end = padded.shape[-1] - extra_pad
#      94 return padded[..., :end]
#
# File ~/birdclef-2024/venv/lib/python3.10/site-packages/torch/nn/functional.py:4495, in pad(input, pad, mode, value)
#    4488         if len(pad) == 4 and (input.dim() == 3 or input.dim() == 4) and mode == 'replicate':
#    4489             # Use slow decomp whose backward will be in terms of index_put.
#    4490             # importlib is required because the import cannot be top level
#    4491             # (cycle) and cannot be nested (TS doesn't support)
#    4492             return importlib.import_module('torch._decomp.decompositions').replication_pad2d(
#    4493                 input, pad
#    4494             )
# -> 4495 return torch._C._nn.pad(input, pad, mode, value)
#
# KeyboardInterrupt:

# %%
df_meta_head.loc[:, "embeddings"] = df_meta_head.loc[:, "filename"].progress_apply(compress)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:16<00:00,  3.31s/it]

# %%
df_meta_head.loc[:, "embeddings"] = df_meta_head.loc[:, "filename"].apply(compress)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Test 1s concatenation

# %%
import librosa

file = "whitenoise.wav"
length = librosa.get_duration(path=(in_root / file))
emb_size = compress(file).shape[0] / 4
print(length, emb_size, emb_size / length)
# Out:
# 10.000022675736961 751.0 75.09982970560158
